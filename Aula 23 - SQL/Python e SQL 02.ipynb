# %% [markdown]
# # Biblioteca pyodbc
#
# 1. Precisamos criar uma conexão com o banco de dados.

# %% [raw]
# dados_conexao = ("Driver={SQL Server};"
#                 "Server=SeuServidor;"
#                 Database=NomeBaseDeDados;")
#
# Se estivéssemos usando outro sistema de banco de dados, nosso driver mudaria. Para saber em outros casos, execute:
# pyodbc.drivers() -> caso não encontre seu driver ali, basta buscar no google por "driver MeuBancoDeDados for pyodbc" e baixar

# %%
import pyodbc
dados_conexao = ("Driver={ODBC Driver 17 for SQL Server};"
                "Server=HueccoMundo;"
                "Database=ContosoRetailDW;"
                "Trusted_Connection=yes;")

conexao = pyodbc.connect(dados_conexao)
print(conexao)
# Out:
# <pyodbc.Connection object at 0x000001C82888E590>

# %%
cursor = conexao.cursor()

# %%
import pandas as pd

produtos_df = pd.read_sql('SELECT * FROM ContosoRetailDW.dbo.DimProduct', conexao)
display(produtos_df)
# Out:
# C:\Users\Peu\AppData\Local\Temp\ipykernel_13168\3742519712.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   produtos_df = pd.read_sql('SELECT * FROM ContosoRetailDW.dbo.DimProduct', conexao)
#       ProductKey ProductLabel                                    ProductName  \
# 0              1      0101001            Contoso 512MB MP3 Player E51 Silver
# 1              2      0101002              Contoso 512MB MP3 Player E51 Blue
# 2              3      0101003               Contoso 1G MP3 Player E100 White
# 3              4      0101004              Contoso 2G MP3 Player E200 Silver
# 4              5      0101005                 Contoso 2G MP3 Player E200 Red
# ...          ...          ...                                            ...
# 2512        2513      0505026    Contoso Bluetooth Active Headphones L15 Red
# 2513        2514      0505027  Contoso Bluetooth Active Headphones L15 White
# 2514        2515      0505028             Contoso In-Line Coupler E180 White
# 2515        2516      0505029             Contoso In-Line Coupler E180 Black
# 2516        2517      0505030            Contoso In-Line Coupler E180 Silver
#
#                                      ProductDescription  \
# 0                    512MB USB driver plays MP3 and WMA
# 1                    512MB USB driver plays MP3 and WMA
# 2     1GB flash memory and USB driver plays MP3 and WMA
# 3      2GB flash memory, LCD display, plays MP3 and WMA
# 4      2GB flash memory, LCD display, plays MP3 and WMA
# ...                                                 ...
# 2512  Play time up to 6 hours, talk time up to 7 hou...
# 2513  Play time up to 6 hours, talk time up to 7 hou...
# 2514  Designed for new modular, different location w...
# 2515  Designed for new modular, different location w...
# 2516  Designed for new modular, different location w...
#
#       ProductSubcategoryKey  Manufacturer BrandName ClassID ClassName StyleID  \
# 0                         1  Contoso, Ltd   Contoso       1   Economy       1
# 1                         1  Contoso, Ltd   Contoso       1   Economy       5
# 2                         1  Contoso, Ltd   Contoso       1   Economy       1
# 3                         1  Contoso, Ltd   Contoso       1   Economy       1
# 4                         1  Contoso, Ltd   Contoso       1   Economy       1
# ...                     ...           ...       ...     ...       ...     ...
# 2512                     33  Contoso, Ltd   Contoso       3    Deluxe    None
# 2513                     33  Contoso, Ltd   Contoso       3    Deluxe    None
# 2514                     33  Contoso, Ltd   Contoso       1   Economy    None
# 2515                     33  Contoso, Ltd   Contoso       1   Economy    None
# 2516                     33  Contoso, Ltd   Contoso       1   Economy    None
#
#       ... UnitCost UnitPrice AvailableForSaleDate StopSaleDate Status  \
# 0     ...     6.62     12.99           2005-05-03         None     On
# 1     ...     6.62     12.99           2005-05-03         None     On
# 2     ...     7.40     14.52           2006-05-13         None     On
# 3     ...    11.00     21.57           2006-12-16         None     On
# 4     ...    11.00     21.57           2006-12-17         None     On
# ...   ...      ...       ...                  ...          ...    ...
# 2512  ...    43.07    129.99           2009-01-02         None     On
# 2513  ...    43.07    129.99           2009-01-02         None     On
# 2514  ...     1.71      3.35           2006-07-28         None     On
# 2515  ...     1.71      3.35           2006-07-28         None     On
# 2516  ...     1.71      3.35           2006-07-28         None     On
#
#      ImageURL  ProductURL ETLLoadID            LoadDate          UpdateDate
# 0        None        None         1 2008-05-25 08:01:12 2008-05-25 08:01:12
# 1        None        None         1 2008-05-26 08:01:12 2008-05-26 08:01:12
# 2        None        None         1 2008-05-27 08:01:12 2008-05-27 08:01:12
# 3        None        None         1 2008-05-28 08:01:12 2008-05-28 08:01:12
# 4        None        None         1 2008-05-29 08:01:12 2008-05-29 08:01:12
# ...       ...         ...       ...                 ...                 ...
# 2512     None        None         1 2007-01-01 00:00:00 2007-01-01 00:00:00
# 2513     None        None         1 2007-01-01 00:00:00 2007-01-01 00:00:00
# 2514     None        None         1 2007-01-01 00:00:00 2007-01-01 00:00:00
# 2515     None        None         1 2007-01-01 00:00:00 2007-01-01 00:00:00
# 2516     None        None         1 2007-01-01 00:00:00 2007-01-01 00:00:00
#
# [2517 rows x 32 columns]
